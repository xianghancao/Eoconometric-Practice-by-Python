# %% [markdown]
# # 课上练习

# %% [markdown]
# 一般认为，一个地区的农业总产值与该地区的农业劳动力、灌溉面积、施用化肥量、农户固定资产和农业机械化水平等因素有很大关系。
#
# 下表给出了1985年我国北方地区12个省市的农业总产值和诸因素的调查数据。
#
# ![农业数据](image/农业数据.png)

# %% [markdown]
# 数据路径："数据/农业数据.csv"
#
# 要求：
#
# （1）建立1985年我国北方地区的农业产出线性回归模型，并剔除不显著的变量。
#
# （2）试解释说明你的分析结论。

# %%
import pandas as pd
pd.read_csv("datasets/农业数据.csv")
# Out:
#      地区   农业总产值   农业劳动力    灌溉面积   化肥用量   户均固定资产    农机动力
# 0    北京   19.61    90.1   33.84    7.5   394.30   435.3
# 1    天津   14.40    95.2   34.95    3.9   567.50   450.7
# 2    河北  149.90  1639.0  357.26   92.4   706.89  2712.6
# 3    山西   55.07   562.6  107.90   31.4   856.37  1118.5
# 4   内蒙古   60.85   462.9   96.49   15.4  1282.81   641.7
# 5    辽宁   87.48   588.9   72.40   61.6   844.74  1129.6
# 6    吉林   73.81   399.7   69.63   36.9  2576.81   647.6
# 7   黑龙江  104.51   425.3   67.95   25.8  1237.16  1305.8
# 8    山东  276.55  2365.6  456.55  152.3  5812.02  3127.9
# 9    河南  200.02  2557.5  318.99  127.9   754.78  2134.5
# 10   陕西   68.18   884.2  117.90   36.1   607.41   764.0
# 11   新疆   49.12   256.1  260.46   15.1  1143.67   523.3
