# %% [markdown]
# # 实验作业：一元线性回归分析（两题任选一题）

# %% [markdown]
# ## 第一题

# %% [markdown]
# 为了研究深圳市地方预算内财政收入与国内生产总值的关系，得到数据如下，
#
# |年份|地方预算内财政收入Y|国内生产总值(GDP)X|
# |---|---|---|
# |1990|21.7037|171.6665|
# |1991|27.3291|236.6630|
# |1992|42.9599|317.3194|
# |1993|67.2507|449.2889|
# |1994|74.3992|615.1933|
# |1995|88.0174|795.6950|
# |1996|131.7490|950.0446|
# |1997|144.7790|1130.0133|
# |1998|164.9067|1289.0190|
# |1999|184.7908|1436.0267|
# |2000|225.0212|1665.4652|
# |2001|265.6532|1954.6539|
#
# 资料来源：《深圳统计年鉴2002》，中国统计出版社
#
# 数据见路径: **"datasets/shenzhen.csv"**

# %% [markdown]
# （1）建立深圳地方预算内财政收入对GDP的回归模型；
#
# （2）使用python回归工具估计所建立模型的参数，解释斜率系数的经济意义；
#
# （3）绘制回归的图形；

# %% [markdown]
# ## 第二题
# 利用Biddle&Hamermesh(1990)提供的数据集SLEEP75，研究在每周用于睡眠的时间和用于有酬工作的时间之间是否有替代关系。具体而言，估计以下模型：
#
# $$
# sleep = \beta_0 + \beta_1totwrk + \mu
# $$
#
# 其中，$sleep$是每周用于晚上睡眠的分钟数，$totwrk$是这一周用于有酬工作的分钟数。

# %% [markdown]
# 数据见路径: **"datasets/sleep75.csv"**

# %% [markdown]
# （1）利用已经学习的一元线性回归的Python方法来获得以上模型的参数
#
# （2）解释当$totwrk$增加时，$sleep$会怎样变化。

# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/sleep75.csv')

# %%
data
# Out:
#      age  black  case  clerical   constru  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12        0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14     9500       1     1   2140
# 2     44      0     3  0.000000  0.000000    17    42500       1     1   4595
# 3     30      0     4  0.000000  0.000000    12    42500       1     1   3211
# 4     64      0     5  0.000000  0.000000    14     2500       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12     5500       1     0   5069
# 702   34      0   703  0.182331  0.030075    10     2500       0     0   5885
# 703   37      0   704  0.182331  0.030075    12     3500       1     0   4719
# 704   54      0   705  0.182331  0.030075    17    32500       1     0   5149
# 705   30      0   706  0.182331  0.030075    16     6750       1     0   4747
#
# ...

# %%
data.columns #列名
# Out:
# Index(['age', 'black', 'case', 'clerical', 'constru', 'educ', 'earns74',
#        'gdhlth', 'inlf', 'leis1', 'leis2', 'leis3', 'smsa', 'lhrwage',
#        'lothinc', 'male', 'marr', 'prot', 'rlxall', 'selfe', 'sleep',
#        'slpnaps', 'south', 'spsepay', 'spwrk75', 'totwrk', 'union', 'worknrm',
#        'workscnd', 'exper', 'yngkid', 'yrsmarr', 'hrwage', 'agesq'],
#       dtype='object')

# %%
data.values
# Out:
# array([[32, 0, 1, ..., 13, '7.070004', 1024],
#        [31, 0, 2, ..., 0, '1.429999', 961],
#        [44, 0, 3, ..., 0, '20.53', 1936],
#        ...,
#        [37, 0, 704, ..., 17, '.', 1369],
#        [54, 0, 705, ..., 22, '.', 2916],
#        [30, 0, 706, ..., 9, '.', 900]], dtype=object)
